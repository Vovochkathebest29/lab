# %% [markdown]
# <a href="https://colab.research.google.com/github/Vovochkathebest29/lab/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import CoolProp.CoolProp as ct 
import matplotlib.pyplot as plt 
t=np.linspace(110,112,100) 
Fluid_name='CH4' 
#10-100 gradus 
V=64 
p=101325 
d=ct.PropsSI('D','P',p,'T',t,Fluid_name) 
m=d*V 
t1=ct.PropsSI('T','P',p,'Q',1,Fluid_name)
plt.plot(t,m,'b') 
plt.scatter(111.65,27000)
plt.grid() 
plt.show() 
print(m)
print("t1=",t1)
print("m1=",m1)
# Out:
# [27186.51729774 27184.63907415 27182.76063282 27180.88197362
#  27179.00309642 27177.12400109 27175.2446875  27173.36515553
#  27171.48540503 27169.60543588 27167.72524795 27165.84484111
#  27163.96421522 27162.08337016 27160.2023058  27158.32102201
#  27156.43951865 27154.55779559 27152.6758527  27150.79368986
#  27148.91130692 27147.02870376 27145.14588024 27143.26283624
#  27141.37957162 27139.49608626 27137.61238001 27135.72845274
#  27133.84430433 27131.95993464 27130.07534354 27128.1905309
#  27126.30549658 27124.42024045 27122.53476238 27120.64906223
#  27118.76313988 27116.87699518 27114.99062801 27113.10403823
#  27111.21722572 27109.33019032 27107.44293192 27105.55545038
#  27103.66774556 27101.77981733 27099.89166555 27098.0032901
#  27096.11469083 27094.22586762 27092.33682033 27090.44754882
#  27088.55805296 27086.66833261 27084.77838764 27082.88821792
#  27080.99782331 27079.10720367 27077.21635887 27075.32528877
# ...

# %%
import numpy as np
import CoolProp.CoolProp as ct 
import matplotlib.pyplot as plt 
t=np.linspace(0,385.15,100) 
Fluid_name='CH4' 
#10-100 gradus 
V=64 
p=101325 
d=ct.PropsSI('D','P',p,'T',t,Fluid_name) 
m=d*V 
plt.plot(t,m,'r')
plt.scatter(111,26550,color="black") 
plt.grid() 
plt.show() 
print(m)

# %%
v=64
p=101325 
t=np.linspace(0,381.15,100)
M=0.0016
R=8
m=p*V*M/(R*t)
plt.plot(t,m,'r')
plt.grid()
plt.show()
# Out:
# <ipython-input-38-e802cedadb27>:6: RuntimeWarning: divide by zero encountered in true_divide
#   m=p*V*M/(R*t)
